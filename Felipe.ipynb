# %%
import pandas as pd

# %%
df = pd.read_csv('criminal-activity.csv')

df.head()
# Out:
# /scratch/slurm-21837/ipykernel_1031459/2719401044.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('criminal-activity.csv')
#    _id Report_Number ReportedDate ReportedTime  Hour DayofWeek ReportedMonth  \
# 0    1  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 1    2  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 2    3  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 3    4  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 4    5  PGHP24000017   2024-01-01        00:21     0    Monday           Jan
#
#                            NIBRS_Coded_Offense NIBRS_Offense_Code  \
# 0                       13A AGGRAVATED ASSAULT                13A
# 1                             13C INTIMIDATION                13C
# 2                       90Z ALL OTHER OFFENSES                90Z
# ...

# %%
df.info()

df.head()

print("Shape:" , df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69476 entries, 0 to 69475
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     69476 non-null  int64
#  1   Report_Number           69471 non-null  object
#  2   ReportedDate            69476 non-null  object
#  3   ReportedTime            69476 non-null  object
#  4   Hour                    69476 non-null  int64
#  5   DayofWeek               69476 non-null  object
#  6   ReportedMonth           69476 non-null  object
#  7   NIBRS_Coded_Offense     69415 non-null  object
#  8   NIBRS_Offense_Code      69408 non-null  object
#  9   NIBRS_Offense_Category  69368 non-null  object
#  10  NIBRS_Offense_Type      69368 non-null  object
#  11  NIBRS_Crime_Against     69368 non-null  object
#  12  NIBRS_Offense_Grouping  69368 non-null  object
#  13  Violation               69440 non-null  object
# ...

# %%
chip = pd.read_csv('criminal-activity.csv')
print (chip.shape[1])
print(chip.columns)
# Out:
# 20
# Index(['_id', 'Report_Number', 'ReportedDate', 'ReportedTime', 'Hour',
#        'DayofWeek', 'ReportedMonth', 'NIBRS_Coded_Offense',
#        'NIBRS_Offense_Code', 'NIBRS_Offense_Category', 'NIBRS_Offense_Type',
#        'NIBRS_Crime_Against', 'NIBRS_Offense_Grouping', 'Violation', 'XCOORD',
#        'YCOORD', 'Zone', 'Tract', 'Neighborhood', 'Block_Address'],
#       dtype='object')
# /scratch/slurm-21837/ipykernel_1031459/762607108.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   chip = pd.read_csv('criminal-activity.csv')

# %%
pd.set_option('display.max_rows', None)
print(chip['Neighborhood'].value_counts())
# Out:
# Neighborhood
# Central Business District    6828
# South Side Flats             4467
# Carrick                      2139
# Shadyside                    1914
# East Liberty                 1853
# East Allegheny               1843
# Bloomfield                   1422
# Knoxville                    1376
# Mount Washington             1336
# Squirrel Hill South          1294
# Brookline                    1232
# Homewood South               1206
# Allentown                    1198
# Crawford-Roberts             1004
# Sheraden                      995
# North Shore                   988
# Marshall-Shadeland            981
# Homewood North                970
# Hazelwood                     957
# Bluff                         921
# East Hills                    879
# Brighton Heights              822
# Central Oakland               813
# Perry South                   802
# Lincoln–Lemington–Belmar      795
# Central Northside             776
# Middle Hill                   776
# ...

# %%
chip['Neighborhood'].value_counts().idxmax()
#Most dangerous one, most amount of crimes
# Out:
# 'Central Business District'

# %%
chip['Neighborhood'].value_counts().idxmin()
#Safest one, least amount of crimes
# Out:
# 'Saint Clair'

# %%
chip['Neighborhood'].value_counts().head(10).plot(kind='bar', figsize=(10,5))
plt.title('Top 10 Neighborhoods by Crime Count')
plt.xlabel('Neighborhood')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt


neighborhood_counts = chip['Neighborhood'].value_counts()


least_common = neighborhood_counts.tail(10)


least_common.plot(kind='bar', figsize=(10, 5), color='orange')


plt.title('10 Least Frequent Neighborhoods')
plt.xlabel('Neighborhood')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion:
# In my analysis, I used the "2024–October 31, 2025 Monthly Criminal Activity Dataset" and focused on the sub-metric of identifying the safest neighborhood in Pittsburgh based on the number of reported crimes in the past few months. After comparing the data, Saint Clair came out as the safest, which makes sense since it had fewer than 30 criminal incidents during that time period. This result aligns well with the overall pattern shown in the dataset.
